# %%
import netCDF4 as nc
from netCDF4 import Dataset
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import datetime 
# %matplotlib inline

# %%
file = '/home/2017LMSOM2/e21608618/Téléchargements/ncep_msl_1948to2017.nc'
data = Dataset(file,'r',format='NETCDF4')

lon = np.array(data.variables['longitude'][:])
lat = np.array(data.variables['latitude'][:])
t = np.array(data.variables['time'][:])
p = np.array(data.variables['msl'][:])/100
pp = p-np.mean(p, axis=0)
pp[pp>-40]=np.nan

# ul = np.array(data.variables['ulwrf'][:])
# dl = np.array(data.variables['dlwrf'][:])
# ds = np.array(data.variables['dswrf'][:])
# lh = np.array(data.variables['lhtfl'][:])
# sh = np.array(data.variables['shtfl'][:])

# %%
data.variables['time']
dateref = datetime.datetime.strptime('1948-1-1',"%Y-%m-%d")
time = []
for i in range(0,len(t)):
    time.append(dateref + datetime.timedelta(hours = int(t[i])))
time = np.array(time)

LON, LAT = np.meshgrid(lon,lat)

# %%
datedebut = datetime.datetime.strptime('1999-12-25',"%Y-%m-%d")
datefin = datetime.datetime.strptime('1999-12-28',"%Y-%m-%d")
ind = np.where((time>=datedebut)&(time<=datefin))[0]

for k in ind:
     
    plt.figure()
    plt.pcolormesh(LON,LAT,pp[k])
    plt.colorbar()
    plt.clim([-60,-40])
    plt.title(time[k])
      
#     plt.figure();

# #     n, bins, patches = plt.hist(p[k].ravel(), bins=50);
#     plt.xlim(-60)
#     plt.show()

# %%
k = 75948

plt.figure()
plt.pcolormesh(LON,LAT,pp[k])
plt.colorbar()
plt.clim([-60,-40])
plt.title(time[k])

# %%
np.where(np.isnan(pp[k])==False)
LON, LAT = np.meshgrid(lon,lat)
import numpy.ma as ma
mask = ma.masked_where(np.isnan(pp[k]),pp[k])
plt.pcolormesh(LON,LAT,mask)
# plt.pcolormesh(pp[k,4:10,30:36])


for i in range(0,len(lat)-6):
    data = mask[i:i+6,30:36]
    if((np.nansum(data)!=0)):
        plt.figure
        plt.pcolormesh(LON[i:i+6,30:36],LAT[i:i+6,30:36],data)
        plt.show()

# %%
#Base d'apprentissage 
k_good = [75946,75947,75948,75949,75950,74492,83304,83305,83306,83307,83308,83310,83311,83312,86269,86270,86271,86272,89212,89213,89214,89215,89216,89217,89218,89219,89220]
center_good = np.where(pp[k_good]==np.nanmin(pp[k_good]))
LON, LAT = np.meshgrid(lon,lat)

datedebut = datetime.datetime.strptime('2009-1-23',"%Y-%m-%d")
datefin = datetime.datetime.strptime('2009-1-25',"%Y-%m-%d")
ind = np.where((time>=datedebut)&(time<=datefin))[0]


for k in ind:
    mask = ma.masked_where(np.isnan(pp[k]),pp[k]) 
    plt.figure()
    plt.pcolormesh(LON,LAT,mask)
    plt.colorbar()
    
    plt.title(k)

# %%
k_good = [75946,75947,75948,75949,74492,83305,83306,83307,83308,83310,83311,83312,86269,86270,86271,86272,89212,89213,89214,89215,89216,89217,89218,89219,89220]
xc = np.zeros(np.shape(k_good))
yc = np.zeros(np.shape(k_good))
np.where(pp[k_good]==np.nanmin(pp[k_good]))

for i in range(0,len(k_good)):
    xc[i] = (np.where(pp[k_good[i]]==np.nanmin(pp[k_good[i]]))[0])
    yc[i] = (np.where(pp[k_good[i]]==np.nanmin(pp[k_good[i]]))[1])
    
print(mask[0,int(xc[0]),int(yc[0])])

for i in range(0,len(k_good)):
    k = [k_good[i]]
    mask = ma.masked_where(np.isnan(pp[k]),pp[k]) 
    plt.figure()

    plt.pcolormesh(LON[int(xc[i])-6:int(xc[i])+6,int(yc[i])-6:int(yc[i])+6],LAT[int(xc[i])-6:int(xc[i])+6,int(yc[i])-6:int(yc[i])+6],mask[0,int(xc[i])-6:int(xc[i])+6,int(yc[i])-6:int(yc[i])+6])
    
    plt.colorbar() 
    plt.title(k)
# Out:
# --
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-155-adcfc9a8035b> in <module>()
#      15     plt.figure()
#      16
# ---> 17     plt.pcolormesh(LON[int(xc[i])-6:int(xc[i])+6,int(yc[i])-6:int(yc[i])+6],LAT[int(xc[i])-6:int(xc[i])+6,int(yc[i])-6:int(yc[i])+6],mask[0,int(xc[i])-6:int(xc[i])+6,int(yc[i])-6:int(yc[i])+6])
#      18
#      19     plt.colorbar()
#
# /opt/linux/anaconda3/4.4.0/lib/python3.6/site-packages/matplotlib/pyplot.py in pcolormesh(*args, **kwargs)
#    3242                       mplDeprecation)
#    3243     try:
# -> 3244         ret = ax.pcolormesh(*args, **kwargs)
#    3245     finally:
#    3246         ax._hold = washold
#
# /opt/linux/anaconda3/4.4.0/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
# ...
